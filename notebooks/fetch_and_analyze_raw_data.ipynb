# %%
import os
import pandas as pd

from data_handling.fetch import get_data, get_date_of_first_entry
from services.bybit import get_bybit_session

session = get_bybit_session()

print(get_date_of_first_entry("BANANAUSDT", session))

for filename in os.listdir("data"):
    df = pd.read_csv(f"data/{filename}")
    df["timestamp"] = pd.to_datetime(df["timestamp"])
    
    print(f"{filename}: {df['timestamp'].max() - df['timestamp'].min()}")
# Out:
# Getting datetime of first entry for BANANAUSDT
# Datetime of first entry 2024-07-19 13:31:00
# 2024-07-19 13:31:00
# ADAUSDT-240.csv: 1249 days 01:00:00
# APTUSDT-240.csv: 669 days 04:00:00
# AVAXUSDT-240.csv: 1067 days 20:00:00
# BANANAUSDT-240.csv: 29 days 20:00:00
# BATUSDT-240.csv: 998 days 01:00:00
# BLZUSDT-240.csv: 803 days 20:00:00
# BNBUSDT-240.csv: 1146 days 00:00:00
# BRETTUSDT-240.csv: 113 days 16:00:00
# BSVUSDT-240.csv: 981 days 21:00:00
# BTCUSDT-240.csv: 1606 days 21:00:00
# C98USDT-240.csv: 1028 days 00:00:00
# CEEKUSDT-240.csv: 761 days 20:00:00
# DOGEUSDT-240.csv: 1172 days 20:00:00
# ETHUSDT-240.csv: 1252 days 09:00:00
# LINKUSDT-240.csv: 1396 days 20:00:00
# MEMEUSDT-240.csv: 288 days 17:00:00
# MNTUSDT-240.csv: 321 days 00:00:00
# ONDOUSDT-240.csv: 207 days 21:00:00
# OPUSDT-240.csv: 808 days 20:00:00
# POPCATUSDT-240.csv: 142 days 21:00:00
# SOLUSDT-240.csv: 1038 days 08:00:00
# SUIUSDT-240.csv: 472 days 16:00:00
# TONUSDT-240.csv: 353 days 00:00:00
# ...

# %%
from datetime import datetime, timedelta
from data_handling.preprocess import (make_train_and_test,
                                      rates_of_change_regression,
                                      get_available_symbols)

for symbol_filename in get_available_symbols(whole_filenames=True):
    res = make_train_and_test(rates_of_change_regression, {"window_size": 64},
                              datetime.now() - timedelta(days=60),
                              symbol_filename,
                              verbose=True)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\marco\Learning\pybit-trading-bot\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\marco\Learning\pybit-trading-bot\.venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...
